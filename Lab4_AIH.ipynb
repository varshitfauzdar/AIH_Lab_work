# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitfauzdar/AIH_Lab_work/blob/main/Lab4_AIH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name="Outcome")

df = pd.concat([X, y], axis=1)

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (569, 31)
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
# ...

# %%
print("Dataset Information:")
print(df.info())

print("\nClass Distribution:")
print(df["Outcome"].value_counts())

print("\nClass Distribution (%):")
print(df["Outcome"].value_counts(normalize=True) * 100)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
summary = df.describe().T

summary["median"] = df.median(numeric_only=True)

summary = summary[
    ["mean", "median", "std", "min", "25%", "50%", "75%", "max"]
]

print(summary)
# Out:
#                                mean      median         std         min  \
# mean radius               14.127292   13.370000    3.524049    6.981000
# mean texture              19.289649   18.840000    4.301036    9.710000
# mean perimeter            91.969033   86.240000   24.298981   43.790000
# mean area                654.889104  551.100000  351.914129  143.500000
# mean smoothness            0.096360    0.095870    0.014064    0.052630
# mean compactness           0.104341    0.092630    0.052813    0.019380
# mean concavity             0.088799    0.061540    0.079720    0.000000
# mean concave points        0.048919    0.033500    0.038803    0.000000
# mean symmetry              0.181162    0.179200    0.027414    0.106000
# mean fractal dimension     0.062798    0.061540    0.007060    0.049960
# radius error               0.405172    0.324200    0.277313    0.111500
# texture error              1.216853    1.108000    0.551648    0.360200
# ...

# %%
missing_values = df.isnull().sum().sum()

print("Missing values:",missing_values)
print(missing_values[missing_values > 0])
# Out:
# Missing values: 0
# []

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
Q1 = X.quantile(0.25)
Q3 = X.quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = ((X < lower_bound) | (X > upper_bound)).sum()

print("Outliers in each feature:")
print(outliers[outliers > 0])
# Out:
# Outliers in each feature:
# mean radius                14
# mean texture                7
# mean perimeter             13
# mean area                  25
# mean smoothness             6
# mean compactness           16
# mean concavity             18
# mean concave points        10
# mean symmetry              15
# mean fractal dimension     15
# radius error               38
# texture error              20
# perimeter error            38
# area error                 65
# smoothness error           30
# compactness error          28
# concavity error            22
# concave points error       19
# symmetry error             27
# fractal dimension error    28
# worst radius               17
# worst texture               5
# worst perimeter            15
# worst area                 35
# worst smoothness            7
# worst compactness          16
# worst concavity            12
# worst symmetry             23
# worst fractal dimension    24
# dtype: int64

# %%
df.hist(figsize=(18, 14), bins=20)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 10))

sns.boxplot(data=X)

plt.xticks(rotation=90)
plt.title("Box Plot of Breast Cancer Features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 14))

correlation = df.corr()

sns.heatmap(
    correlation,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))

sns.countplot(x=df["Outcome"])

plt.title("Class Distribution")
plt.xlabel("Outcome")
plt.ylabel("Count")

plt.show()

print(df["Outcome"].value_counts())
# Out:
# Outcome
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (569, 30)
# Target shape: (569,)

# %%
print("Unique target values:", y.unique())
# Out:
# Unique target values: [0 1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (455, 30)
# Testing data: (114, 30)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=X_train.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=X_test.columns,
    index=X_test.index
)

X_train_scaled.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 546    -1.072001     -0.658425       -1.088080  -0.939274        -0.135940
# 432     1.748743      0.066502        1.751157   1.745559         1.274468
# 174    -0.974734     -0.931124       -0.997709  -0.867589        -0.613515
# 221    -0.145103     -1.215186       -0.123013  -0.253192         0.664482
# 289    -0.771617     -0.081211       -0.803700  -0.732927        -0.672282
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 546         -1.008718       -0.968359            -1.102032       0.281062
# 432          0.842288        1.519852             1.994664      -0.293045
# 174         -1.138154       -1.092292            -1.243358       0.434395
# 221          0.286762       -0.129729            -0.098605       0.555635
# 289         -1.006099       -0.798502            -0.684484       0.737495
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...
